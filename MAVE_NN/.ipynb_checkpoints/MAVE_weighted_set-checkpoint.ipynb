# %%
import sys
import os
import pickle

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import logomaker

import mavenn

os.chdir("/mnt/c/Users/Maya/Documents/03_Kinases/")

# %%
with open('splimlib_mave.pickle', 'rb') as f:
    df_sml = pickle.load(f)

# %%
df_sml.head()
# Out:
#                mutations    ct_2  ct_1  ct_0 sequences
# 0  6L/7aI/8aA/9L/11F/13M  1185.0  33.0   6.0    LIALFM
# 1      6F/7aP/9W/11L/13M   903.0  81.0  15.0    FPΔWLM
# 2      6L/7aF/9L/11I/13I   899.0   2.0   8.0    LFΔLII
# 3  6A/7aI/8aA/9L/11L/13I   893.0   3.0  19.0    AIALLI
# 4      6W/7aI/9F/11L/13V   880.0  34.0  20.0    WIΔFLV

# %%
from sklearn.model_selection import train_test_split

# %%
data_df = df_sml

# %%
x = df_sml['sequences'].values
y = df_sml[['ct_0', 'ct_1', 'ct_2']].values

# %%
L = len(data_df['sequences'][0])
y_cols = data_df.columns[1:-1]
Y = len(y_cols)
print(f'L={L}, Y={Y}')
# Out:
# L=6, Y=3

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=11056)

# %%
len(x_train), len(x_test), len(y_train), len(y_test)
# Out:
# (308824, 77207, 308824, 77207)

# %%
# Show dataset sizes
print(f'Training set size: {len(x_train):6,d} observations')
print(f'Test set size    : {len(x_test):6,d} observations')
# Out:
# Training set size: 308,824 observations
# Test set size    : 77,207 observations

# %%
sml_alphabet = np.array(['A','G','P','Y','D','K','M','V','I','L','F','W','Δ'])

# %%
# Define model
model = mavenn.Model(regression_type='MPA',
                     L=L,
                     Y=Y,
                     alphabet=sml_alphabet,
                     gpmap_type='additive',
                     mpa_hidden_nodes=100)

# Set training data
model.set_data(x=x_train,
               y=y_train,
               shuffle=True)

# Fit model to data
model.fit(learning_rate=.005,
          epochs=1000,
          batch_size=500,
          early_stopping=True,
          early_stopping_patience=10,
          linear_initialization=True)

# Save model
model.save('splimlib_mpa_additive')
# Out:
# N = 308,824 observations set as training data.
# Using 20.1% for validation.
# Data shuffled.
# Time to set data: 2.31 sec.
#
# LSMR            Least-squares solution of  Ax = b
#
# The matrix A has   246635 rows  and       78 cols
# damp = 0.00000000000000e+00
#
# atol = 1.00e-06                 conlim = 1.00e+08
#
# btol = 1.00e-06             maxiter =       78
#
#
#    itn      x(1)       norm r    norm Ar  compatible   LS      norm A   cond A
#      0  0.00000e+00  3.259e+02  6.230e+04   1.0e+00  5.9e-01
#      1  1.23529e-01  2.633e+02  5.208e+03   8.1e-01  6.1e-02  3.2e+02  1.0e+00
#      2  6.26699e-02  2.613e+02  6.011e+02   8.0e-01  6.3e-03  3.6e+02  2.0e+00
#      3  5.80043e-02  2.613e+02  3.504e+02   8.0e-01  3.5e-03  3.8e+02  3.1e+00
#      4  4.80563e-02  2.612e+02  2.608e+02   8.0e-01  2.5e-03  4.0e+02  3.8e+00
#      5  4.14625e-02  2.612e+02  2.279e+02   8.0e-01  2.1e-03  4.2e+02  6.1e+00
#      6  2.38253e-02  2.612e+02  1.708e+02   8.0e-01  1.5e-03  4.4e+02  6.4e+00
#      7  3.49924e-03  2.611e+02  6.730e+01   8.0e-01  5.5e-04  4.7e+02  4.2e+00
#      8 -5.95245e-04  2.611e+02  8.049e+00   8.0e-01  6.3e-05  4.9e+02  4.2e+00
#      9 -6.16169e-04  2.611e+02  2.508e+00   8.0e-01  1.9e-05  5.1e+02  4.2e+00
#     10 -6.31147e-04  2.611e+02  4.007e-01   8.0e-01  2.9e-06  5.4e+02  4.2e+00
#     11 -6.27589e-04  2.611e+02  6.127e-02   8.0e-01  4.2e-07  5.6e+02  4.2e+00
#
# LSMR finished
# The least-squares solution is good enough, given atol
# istop =       2    normr = 2.6e+02
#     normA = 5.6e+02    normAr = 6.1e-02
# itn   =      11    condA = 4.2e+00
#     normx = 7.0e-01
#     11 -6.27589e-04   2.611e+02  6.127e-02
#    8.0e-01  4.2e-07   5.6e+02  4.2e+00
# Linear regression time: 0.1213 sec
# Epoch 1/1000
# 494/494 [==============================] - 1s 2ms/step - loss: 18700.8125 - I_var: -0.0014 - val_loss: 18686.8555 - val_I_var: -0.0025
# Epoch 2/1000
# 494/494 [==============================] - 1s 2ms/step - loss: 18675.9297 - I_var: -1.8178e-04 - val_loss: 18666.3496 - val_I_var: -0.0013
# Epoch 3/1000
# 494/494 [==============================] - 1s 2ms/step - loss: 18666.8242 - I_var: 7.8944e-06 - val_loss: 18664.3945 - val_I_var: -0.0016
# Epoch 4/1000
# 494/494 [==============================] - 1s 2ms/step - loss: 18662.9609 - I_var: 2.6231e-04 - val_loss: 18664.0859 - val_I_var: -0.0017
# Epoch 5/1000
# 494/494 [==============================] - 1s 2ms/step - loss: 18661.1348 - I_var: 3.7654e-04 - val_loss: 18658.7461 - val_I_var: -0.0012
# Epoch 6/1000
# 494/494 [==============================] - 1s 2ms/step - loss: 18657.1719 - I_var: 5.6310e-04 - val_loss: 18658.9434 - val_I_var: -0.0012
# Epoch 7/1000
# 494/494 [==============================] - 1s 2ms/step - loss: 18658.0137 - I_var: 4.3670e-04 - val_loss: 18659.9414 - val_I_var: -0.0012
# Epoch 8/1000
# 494/494 [==============================] - 1s 2ms/step - loss: 18658.0156 - I_var: 4.9310e-04 - val_loss: 18659.7559 - val_I_var: -0.0012
# Epoch 9/1000
# 494/494 [==============================] - 1s 2ms/step - loss: 18658.6738 - I_var: 4.6129e-04 - val_loss: 18659.1016 - val_I_var: -0.0012
# Epoch 10/1000
# 494/494 [==============================] - 1s 2ms/step - loss: 18654.9512 - I_var: 5.4815e-04 - val_loss: 18671.8184 - val_I_var: -0.0021
# Epoch 11/1000
# 494/494 [==============================] - 1s 2ms/step - loss: 18659.5273 - I_var: 3.6944e-04 - val_loss: 18658.9414 - val_I_var: -0.0012
# Epoch 12/1000
# 494/494 [==============================] - 1s 2ms/step - loss: 18656.3984 - I_var: 6.1806e-04 - val_loss: 18660.0996 - val_I_var: -0.0012
# Epoch 13/1000
# 494/494 [==============================] - 1s 2ms/step - loss: 18656.4746 - I_var: 5.3638e-04 - val_loss: 18663.6230 - val_I_var: -0.0015
# Epoch 14/1000
# 494/494 [==============================] - 1s 2ms/step - loss: 18657.2383 - I_var: 5.0805e-04 - val_loss: 18658.9902 - val_I_var: -0.0012
# Epoch 15/1000
# 494/494 [==============================] - 1s 2ms/step - loss: 18657.3789 - I_var: 5.0412e-04 - val_loss: 18658.8887 - val_I_var: -0.0012
# Training time: 19.2 seconds
# Model saved to these files:
# 	splimlib_mpa_additive.pickle
# 	splimlib_mpa_additive.h5

# %%
model = mavenn.load('splimlib_mpa_additive')

# Get G-P map parameters in matrix form
theta = model.get_theta(gauge='uniform')

# Create grid in phi space
phi_lim = [-5, 3]
phi_grid = np.linspace(phi_lim[0], phi_lim[1], 1000)

# Create array of allowable y values
Y = model.model.Y    # Y = number of bins
y_lim = [-.5, Y-.5]
y_all = range(Y)

# Compute matrix of p(y|phi) values
measurement_process = model.p_of_y_given_phi(y_all, phi_grid)

# Create figure with two panels
fig, axs = plt.subplots(1,2,figsize=[12,4])

# Left panel: draw logo using logomaker
ax = axs[0]
logo = logomaker.Logo(theta['logomaker_df'], ax=ax)
ax.set_ylabel(r'parameter value ($\theta_{l:c}$)')
ax.set_xlabel(r'position ($l$)')
ax.set_title('G-P map parameters')

# Right panel: draw measurement process as heatmap
ax = axs[1]
im = ax.imshow(measurement_process,
               cmap='Greens',
               extent=phi_lim+y_lim,
               vmin=0,
               origin='lower',
               interpolation='nearest',
               aspect="auto")
ax.set_yticks(y_all)
ax.set_ylabel('bin number (y)')
ax.set_xlabel('latent phenotype ($\phi$)')
ax.set_title('measurement process: additive')
cb = plt.colorbar(im)
cb.set_label('probability  $p(y|\phi)$', rotation=-90, va="bottom")

# Fix up plot
fig.tight_layout(w_pad=3)
fig.savefig('splimlib_additive_g-p_map_mpa_visualization.png')
plt.show()
# Out:
# Model loaded from these files:
# 	splimlib_mpa_additive.pickle
# 	splimlib_mpa_additive.h5

# %%
# Define model
model = mavenn.Model(regression_type='MPA',
                     L=L,
                     Y=Y,
                     alphabet=sml_alphabet,
                     gpmap_type='pairwise',
                     mpa_hidden_nodes=100)

# Set training data
model.set_data(x=x_train,
               y=y_train,
               shuffle=True)

# Fit model to data
model.fit(learning_rate=.005,
          epochs=1000,
          batch_size=500,
          early_stopping=True,
          early_stopping_patience=10,
          linear_initialization=True)

# Save model
model.save('splimlib_mpa_pairwise')
# Out:
# N = 308,824 observations set as training data.
# Using 20.0% for validation.
# Data shuffled.
# Time to set data: 3.22 sec.
#
# LSMR            Least-squares solution of  Ax = b
#
# The matrix A has   246997 rows  and       78 cols
# damp = 0.00000000000000e+00
#
# atol = 1.00e-06                 conlim = 1.00e+08
#
# btol = 1.00e-06             maxiter =       78
#
#
#    itn      x(1)       norm r    norm Ar  compatible   LS      norm A   cond A
#      0  0.00000e+00  3.261e+02  6.246e+04   1.0e+00  5.9e-01
#      1  1.23395e-01  2.633e+02  5.245e+03   8.1e-01  6.1e-02  3.2e+02  1.0e+00
#      2  6.17793e-02  2.613e+02  6.718e+02   8.0e-01  7.1e-03  3.6e+02  2.0e+00
#      3  5.33402e-02  2.613e+02  3.472e+02   8.0e-01  3.5e-03  3.8e+02  3.1e+00
#      4  4.50071e-02  2.612e+02  2.466e+02   8.0e-01  2.4e-03  4.0e+02  3.5e+00
#      5  3.92421e-02  2.612e+02  2.151e+02   8.0e-01  2.0e-03  4.2e+02  5.8e+00
#      6  2.52113e-02  2.612e+02  1.683e+02   8.0e-01  1.5e-03  4.4e+02  6.7e+00
#      7  3.48522e-03  2.612e+02  6.718e+01   8.0e-01  5.5e-04  4.7e+02  4.2e+00
#      8 -7.01954e-04  2.611e+02  1.018e+01   8.0e-01  7.9e-05  4.9e+02  4.2e+00
#      9 -7.99274e-04  2.611e+02  3.294e+00   8.0e-01  2.5e-05  5.1e+02  4.2e+00
#     10 -8.11494e-04  2.611e+02  4.795e-01   8.0e-01  3.4e-06  5.4e+02  4.2e+00
#     11 -8.08746e-04  2.611e+02  9.792e-02   8.0e-01  6.7e-07  5.6e+02  4.2e+00
#
# LSMR finished
# The least-squares solution is good enough, given atol
# istop =       2    normr = 2.6e+02
#     normA = 5.6e+02    normAr = 9.8e-02
# itn   =      11    condA = 4.2e+00
#     normx = 6.9e-01
#     11 -8.08746e-04   2.611e+02  9.792e-02
#    8.0e-01  6.7e-07   5.6e+02  4.2e+00
# Linear regression time: 0.1364 sec
# Epoch 1/1000
# 494/494 [==============================] - 6s 13ms/step - loss: 18722.2656 - I_var: -0.0033 - val_loss: 18703.8750 - val_I_var: -0.0011
# Epoch 2/1000
# 494/494 [==============================] - 6s 12ms/step - loss: 18681.0605 - I_var: -8.0505e-04 - val_loss: 18704.3809 - val_I_var: -0.0016
# Epoch 3/1000
# 494/494 [==============================] - 5s 10ms/step - loss: 18671.4434 - I_var: -3.7433e-04 - val_loss: 18691.4258 - val_I_var: -9.2630e-04
# Epoch 4/1000
# 494/494 [==============================] - 5s 9ms/step - loss: 18665.8848 - I_var: 9.3165e-05 - val_loss: 18684.0430 - val_I_var: -3.6720e-05
# Epoch 5/1000
# 494/494 [==============================] - 5s 10ms/step - loss: 18657.4160 - I_var: 8.8299e-04 - val_loss: 18691.2656 - val_I_var: -5.7404e-04
# Epoch 6/1000
# 494/494 [==============================] - 5s 10ms/step - loss: 18633.8809 - I_var: 0.0030 - val_loss: 18713.4648 - val_I_var: -0.0021
# Epoch 7/1000
# 494/494 [==============================] - 5s 10ms/step - loss: 18591.0234 - I_var: 0.0068 - val_loss: 18757.0977 - val_I_var: -0.0052
# Epoch 8/1000
# 494/494 [==============================] - 5s 9ms/step - loss: 18555.4570 - I_var: 0.0100 - val_loss: 18746.8145 - val_I_var: -0.0040
# Epoch 9/1000
# 494/494 [==============================] - 5s 9ms/step - loss: 18519.2461 - I_var: 0.0133 - val_loss: 18822.7930 - val_I_var: -0.0097
# Epoch 10/1000
# 494/494 [==============================] - 5s 10ms/step - loss: 18491.4824 - I_var: 0.0159 - val_loss: 18821.6152 - val_I_var: -0.0094
# Epoch 11/1000
# 494/494 [==============================] - 5s 10ms/step - loss: 18471.6953 - I_var: 0.0177 - val_loss: 18893.4062 - val_I_var: -0.0149
# Epoch 12/1000
# 494/494 [==============================] - 5s 10ms/step - loss: 18446.9258 - I_var: 0.0201 - val_loss: 18902.7402 - val_I_var: -0.0153
# Epoch 13/1000
# 494/494 [==============================] - 6s 12ms/step - loss: 18425.9512 - I_var: 0.0222 - val_loss: 18909.7188 - val_I_var: -0.0155
# Epoch 14/1000
# 494/494 [==============================] - 6s 11ms/step - loss: 18405.4277 - I_var: 0.0241 - val_loss: 18917.6992 - val_I_var: -0.0160
# Training time: 116.1 seconds
# Model saved to these files:
# 	splimlib_mpa_pairwise.pickle
# 	splimlib_mpa_pairwise.h5

# %%
# Load model
model = mavenn.load('splimlib_mpa_pairwise')

# Get G-P map parameters in matrix form
theta = model.get_theta(gauge='uniform')

# Create grid in phi space
phi_lim = [-5, 3]
phi_grid = np.linspace(phi_lim[0], phi_lim[1], 1000)

# Create array of allowable y values
Y = model.model.Y    # Y = number of bins
y_lim = [-.5, Y-.5]
y_all = range(Y)

# Compute matrix of p(y|phi) values
measurement_process = model.p_of_y_given_phi(y_all, phi_grid)

# Create figure with two panels
fig, axs = plt.subplots(1,2,figsize=[12,4])

# Left panel: draw logo using logomaker
ax = axs[0]
logo = logomaker.Logo(theta['logomaker_df'], ax=ax)
ax.set_ylabel(r'parameter value ($\theta_{l:c}$)')
ax.set_xlabel(r'position ($l$)')
ax.set_title('G-P map parameters')

# Right panel: draw measurement process as heatmap
ax = axs[1]
im = ax.imshow(measurement_process,
               cmap='Greens',
               extent=phi_lim+y_lim,
               vmin=0,
               origin='lower',
               interpolation='nearest',
               aspect="auto")
ax.set_yticks(y_all)
ax.set_ylabel('bin number (y)')
ax.set_xlabel('latent phenotype ($\phi$)')
ax.set_title('measurement process: pairwise')
cb = plt.colorbar(im)
cb.set_label('probability  $p(y|\phi)$', rotation=-90, va="bottom")

# Fix up plot
fig.tight_layout(w_pad=3)
fig.savefig('splimlib_pairwise_g-p_map_mpa_visualization.png')
plt.show()
# Out:
# Model loaded from these files:
# 	splimlib_mpa_pairwise.pickle
# 	splimlib_mpa_pairwise.h5

# %%
# Define model
model = mavenn.Model(regression_type='MPA',
                     L=L,
                     Y=Y,
                     alphabet=sml_alphabet,
                     gpmap_type='neighbor',
                     mpa_hidden_nodes=100)

# Set training data
model.set_data(x=x_train,
               y=y_train,
               shuffle=True)

# Fit model to data
model.fit(learning_rate=.005,
          epochs=1000,
          batch_size=500,
          early_stopping=True,
          early_stopping_patience=10,
          linear_initialization=True)

# Save model
model.save('splimlib_mpa_neighbour')
# Out:
# N = 308,824 observations set as training data.
# Using 20.0% for validation.
# Data shuffled.
# Time to set data: 2.87 sec.
#
# LSMR            Least-squares solution of  Ax = b
#
# The matrix A has   247048 rows  and       78 cols
# damp = 0.00000000000000e+00
#
# atol = 1.00e-06                 conlim = 1.00e+08
#
# btol = 1.00e-06             maxiter =       78
#
#
#    itn      x(1)       norm r    norm Ar  compatible   LS      norm A   cond A
#      0  0.00000e+00  3.267e+02  6.259e+04   1.0e+00  5.9e-01
#      1  1.23062e-01  2.638e+02  5.294e+03   8.1e-01  6.2e-02  3.2e+02  1.0e+00
#      2  6.38425e-02  2.618e+02  6.376e+02   8.0e-01  6.7e-03  3.6e+02  2.0e+00
#      3  5.70389e-02  2.618e+02  3.437e+02   8.0e-01  3.5e-03  3.8e+02  3.1e+00
#      4  4.85400e-02  2.617e+02  2.509e+02   8.0e-01  2.4e-03  4.0e+02  3.6e+00
#      5  4.20497e-02  2.617e+02  2.191e+02   8.0e-01  2.0e-03  4.2e+02  6.0e+00
#      6  2.71319e-02  2.617e+02  1.698e+02   8.0e-01  1.5e-03  4.4e+02  6.5e+00
#      7  5.88544e-03  2.617e+02  6.939e+01   8.0e-01  5.7e-04  4.7e+02  4.1e+00
#      8  1.59169e-03  2.617e+02  7.977e+00   8.0e-01  6.2e-05  4.9e+02  4.1e+00
#      9  1.50873e-03  2.617e+02  2.449e+00   8.0e-01  1.8e-05  5.1e+02  4.1e+00
#     10  1.51716e-03  2.617e+02  3.847e-01   8.0e-01  2.7e-06  5.4e+02  4.1e+00
#     11  1.51799e-03  2.617e+02  8.729e-02   8.0e-01  6.0e-07  5.6e+02  4.1e+00
#
# LSMR finished
# The least-squares solution is good enough, given atol
# istop =       2    normr = 2.6e+02
#     normA = 5.6e+02    normAr = 8.7e-02
# itn   =      11    condA = 4.1e+00
#     normx = 6.9e-01
#     11  1.51799e-03   2.617e+02  8.729e-02
#    8.0e-01  6.0e-07   5.6e+02  4.1e+00
# Linear regression time: 0.1245 sec
# Epoch 1/1000
# 495/495 [==============================] - 6s 13ms/step - loss: 18757.9062 - I_var: -0.0027 - val_loss: 18491.0957 - val_I_var: 0.0012
# Epoch 2/1000
# 495/495 [==============================] - 5s 11ms/step - loss: 18729.1074 - I_var: -0.0015 - val_loss: 18486.7051 - val_I_var: 9.5029e-04
# Epoch 3/1000
# 495/495 [==============================] - 5s 11ms/step - loss: 18718.8750 - I_var: -7.2336e-04 - val_loss: 18481.9824 - val_I_var: 0.0012
# Epoch 4/1000
# 495/495 [==============================] - 5s 10ms/step - loss: 18712.1914 - I_var: -3.8534e-04 - val_loss: 18477.5020 - val_I_var: 0.0016
# Epoch 5/1000
# 495/495 [==============================] - 5s 11ms/step - loss: 18699.8398 - I_var: 7.0470e-04 - val_loss: 18480.1309 - val_I_var: 0.0014
# Epoch 6/1000
# 495/495 [==============================] - 5s 10ms/step - loss: 18685.4258 - I_var: 0.0018 - val_loss: 18515.7051 - val_I_var: -0.0016
# Epoch 7/1000
# 495/495 [==============================] - 5s 11ms/step - loss: 18679.2051 - I_var: 0.0025 - val_loss: 18521.1172 - val_I_var: -0.0016
# Epoch 8/1000
# 495/495 [==============================] - 5s 11ms/step - loss: 18672.9141 - I_var: 0.0032 - val_loss: 18495.2656 - val_I_var: 3.6329e-04
# Epoch 9/1000
# 495/495 [==============================] - 5s 10ms/step - loss: 18664.0195 - I_var: 0.0038 - val_loss: 18528.1172 - val_I_var: -0.0020
# Epoch 10/1000
# 495/495 [==============================] - 5s 10ms/step - loss: 18663.4844 - I_var: 0.0039 - val_loss: 18523.3574 - val_I_var: -0.0016
# Epoch 11/1000
# 495/495 [==============================] - 4s 9ms/step - loss: 18663.2461 - I_var: 0.0042 - val_loss: 18552.4277 - val_I_var: -0.0044
# Epoch 12/1000
# 495/495 [==============================] - 5s 9ms/step - loss: 18664.2227 - I_var: 0.0041 - val_loss: 18526.2441 - val_I_var: -0.0018
# Epoch 13/1000
# 495/495 [==============================] - 5s 10ms/step - loss: 18662.7129 - I_var: 0.0041 - val_loss: 18535.3398 - val_I_var: -0.0026
# Epoch 14/1000
# 495/495 [==============================] - 5s 10ms/step - loss: 18660.7051 - I_var: 0.0045 - val_loss: 18542.3789 - val_I_var: -0.0031
# Training time: 112.3 seconds
# Model saved to these files:
# 	splimlib_mpa_neighbour.pickle
# 	splimlib_mpa_neighbour.h5

# %%
# Load model
model = mavenn.load('splimlib_mpa_neighbour')

# Get G-P map parameters in matrix form
theta = model.get_theta(gauge='uniform')

# Create grid in phi space
phi_lim = [-5, 3]
phi_grid = np.linspace(phi_lim[0], phi_lim[1], 1000)

# Create array of allowable y values
Y = model.model.Y    # Y = number of bins
y_lim = [-.5, Y-.5]
y_all = range(Y)

# Compute matrix of p(y|phi) values
measurement_process = model.p_of_y_given_phi(y_all, phi_grid)

# Create figure with two panels
fig, axs = plt.subplots(1,2,figsize=[12,4])

# Left panel: draw logo using logomaker
ax = axs[0]
logo = logomaker.Logo(theta['logomaker_df'], ax=ax)
ax.set_ylabel(r'parameter value ($\theta_{l:c}$)')
ax.set_xlabel(r'position ($l$)')
ax.set_title('G-P map parameters')

# Right panel: draw measurement process as heatmap
ax = axs[1]
im = ax.imshow(measurement_process,
               cmap='Greens',
               extent=phi_lim+y_lim,
               vmin=0,
               origin='lower',
               interpolation='nearest',
               aspect="auto")
ax.set_yticks(y_all)
ax.set_ylabel('bin number (y)')
ax.set_xlabel('latent phenotype ($\phi$)')
ax.set_title('measurement process: neighbour')
cb = plt.colorbar(im)
cb.set_label('probability  $p(y|\phi)$', rotation=-90, va="bottom")

# Fix up plot
fig.tight_layout(w_pad=3)
fig.savefig('splimlib_neighbour_g-p_map_mpa_visualization.png')
plt.show()
# Out:
# Model loaded from these files:
# 	splimlib_mpa_neighbour.pickle
# 	splimlib_mpa_neighbour.h5

# %%
# Define model
model = mavenn.Model(regression_type='MPA',
                     L=L,
                     Y=Y,
                     alphabet=sml_alphabet,
                     gpmap_type='blackbox',
                     gpmap_kwargs={
                         'hidden_layer_sizes': [5]*5
                     })

# Set training data
model.set_data(x=x_train,
               y=y_train,
               shuffle=True)

# Fit model to data
model.fit(learning_rate=.005,
          epochs=1000,
          batch_size=500,
          early_stopping=True,
          early_stopping_patience=10,
          linear_initialization=False)

# Save model
model.save('splimlib_mpa_blackbox')
# Out:
# N = 308,824 observations set as training data.
# Using 20.0% for validation.
# Data shuffled.
# Time to set data: 3.12 sec.
# Epoch 1/1000
# 494/494 [==============================] - 2s 4ms/step - loss: 18705.8867 - I_var: -0.0014 - val_loss: 18623.6953 - val_I_var: 7.5951e-04
# Epoch 2/1000
# 494/494 [==============================] - 1s 3ms/step - loss: 18686.6543 - I_var: -3.3886e-04 - val_loss: 18615.9199 - val_I_var: 6.9013e-04
# Epoch 3/1000
# 494/494 [==============================] - 1s 3ms/step - loss: 18680.6074 - I_var: -2.1924e-04 - val_loss: 18612.1152 - val_I_var: 0.0011
# Epoch 4/1000
# 494/494 [==============================] - 1s 3ms/step - loss: 18680.5430 - I_var: -2.0508e-04 - val_loss: 18609.6230 - val_I_var: 0.0011
# Epoch 5/1000
# 494/494 [==============================] - 1s 3ms/step - loss: 18680.1582 - I_var: -1.4184e-04 - val_loss: 18607.9199 - val_I_var: 0.0013
# Epoch 6/1000
# 494/494 [==============================] - 1s 3ms/step - loss: 18677.6836 - I_var: -7.6521e-05 - val_loss: 18608.6543 - val_I_var: 0.0012
# Epoch 7/1000
# 494/494 [==============================] - 1s 3ms/step - loss: 18678.6113 - I_var: -5.5932e-05 - val_loss: 18615.5273 - val_I_var: 8.7734e-04
# Epoch 8/1000
# 494/494 [==============================] - 2s 3ms/step - loss: 18676.0508 - I_var: 1.4170e-04 - val_loss: 18613.6797 - val_I_var: 9.9447e-04
# Epoch 9/1000
# 494/494 [==============================] - 1s 3ms/step - loss: 18675.6289 - I_var: 2.7374e-04 - val_loss: 18638.0898 - val_I_var: -7.0613e-04
# Epoch 10/1000
# 494/494 [==============================] - 1s 3ms/step - loss: 18672.8945 - I_var: 5.7808e-04 - val_loss: 18620.8711 - val_I_var: 6.0437e-04
# Epoch 11/1000
# 494/494 [==============================] - 1s 3ms/step - loss: 18670.9160 - I_var: 8.0489e-04 - val_loss: 18618.7578 - val_I_var: 7.0857e-04
# Epoch 12/1000
# 494/494 [==============================] - 2s 3ms/step - loss: 18668.6113 - I_var: 9.9050e-04 - val_loss: 18636.2539 - val_I_var: -5.3119e-04
# Epoch 13/1000
# 494/494 [==============================] - 1s 3ms/step - loss: 18664.9805 - I_var: 0.0014 - val_loss: 18628.4121 - val_I_var: -1.1983e-05
# Epoch 14/1000
# 494/494 [==============================] - 1s 3ms/step - loss: 18661.2188 - I_var: 0.0017 - val_loss: 18624.6934 - val_I_var: 3.7822e-04
# Epoch 15/1000
# 494/494 [==============================] - 1s 3ms/step - loss: 18656.7910 - I_var: 0.0022 - val_loss: 18632.8672 - val_I_var: -3.2825e-04
# Training time: 25.0 seconds
# Model saved to these files:
# 	splimlib_mpa_blackbox.pickle
# 	splimlib_mpa_blackbox.h5

# %%
# Load model
model = mavenn.load('splimlib_mpa_blackbox')

# Get G-P map parameters in matrix form
theta = model.get_theta(gauge='uniform')

# Create grid in phi space
phi_lim = [-5, 3]
phi_grid = np.linspace(phi_lim[0], phi_lim[1], 1000)

# Create array of allowable y values
Y = model.model.Y    # Y = number of bins
y_lim = [-.5, Y-.5]
y_all = range(Y)

# Compute matrix of p(y|phi) values
measurement_process = model.p_of_y_given_phi(y_all, phi_grid)

# Create figure with two panels
fig, ax = plt.subplots(1,1,figsize=[6,4])

im = ax.imshow(measurement_process,
               cmap='Greens',
               extent=phi_lim+y_lim,
               vmin=0,
               origin='lower',
               interpolation='nearest',
               aspect="auto")
ax.set_yticks(y_all)
ax.set_ylabel('bin number (y)')
ax.set_xlabel('latent phenotype ($\phi$)')
ax.set_title('measurement process: blackbox')
cb = plt.colorbar(im)
cb.set_label('probability  $p(y|\phi)$', rotation=-90, va="bottom")

# Fix up plot
fig.tight_layout(w_pad=3)
fig.savefig('splimbli_blackbox_mpa_visualization.png')
plt.show()
# Out:
# Model loaded from these files:
# 	splimlib_mpa_blackbox.pickle
# 	splimlib_mpa_blackbox.h5

# %%
# Show training history
print('On test data:')
x_test = df_sml['sequences'].values
y_test = df_sml[y_cols].values

# Compute likelihood information
I_var, dI_var =  model.I_variational(x=x_test, y=y_test)
print(f'I_var_test: {I_var:.3f} +- {dI_var:.3f} bits') 

# Compute predictive information
I_pred, dI_pred = model.I_predictive(x=x_test, y=y_test)
print(f'I_pred_test: {I_pred:.3f} +- {dI_pred:.3f} bits')

I_var_hist = model.history['I_var']
val_I_var_hist = model.history['val_I_var']

fig, ax = plt.subplots(1,1,figsize=[4,4])
ax.plot(I_var_hist, label='I_var_train')
ax.plot(val_I_var_hist, label='I_var_val')
ax.axhline(I_var, color='C2', linestyle=':', label='I_var_test')
ax.axhline(I_pred, color='C3', linestyle=':', label='I_pred_test')
ax.legend()
ax.set_xlabel('epochs')
ax.set_ylabel('bits')
ax.set_title('training history')
ax.set_ylim([0, I_pred*1.2]);
# Out:
# On test data:
# I_var_test: -0.037 +- 0.000 bits
# I_pred_test: 0.002 +- 0.000 bits
